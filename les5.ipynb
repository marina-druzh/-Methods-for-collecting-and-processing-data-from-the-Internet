# %% [markdown]
# # ДЗ
# 1. Доработать паука в имеющемся проекте, чтобы он формировал item по структуре:
#   * Наименование вакансии
#   * Зарплата от
#   * Зарплата до
#   * Ссылку на саму вакансию
#
#  и складывал все записи в БД.
#
#
#  2. Создать в имеющемся проекте второго паука по сбору вакансий с сайта rabota.ru. Паук должен формировать item'ы по аналогичной структуре и складывать данные также в БД.

# %% [markdown]
# # 1. Разархивируем данные

# %%
# !unzip scrapy.zip

# %%
# %cd scrapy
# Out:
# /content/scrapy

# %% [markdown]
# # 2. Установкка Mongo

# %%
# !apt install mongodb >log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !service mongodb start
# Out:
#  * Starting database mongodb
#    ...done.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo) (2.2.1)

# %% [markdown]
# # 3. Установка scrapy

# %%
# !pip install scrapy

# %% [markdown]
# # 4. Запуск паука

# %%
# !scrapy crawl hh_ru
# Out:
# 2023-01-11 20:08:16 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: parser_job)
# 2023-01-11 20:08:16 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.8.16 (default, Dec  7 2022, 01:12:13) - [GCC 7.5.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 39.0.0, Platform Linux-5.10.147+-x86_64-with-glibc2.27
# 2023-01-11 20:08:16 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'parser_job',
#  'DOWNLOAD_DELAY': 0.5,
#  'NEWSPIDER_MODULE': 'parser_job.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['parser_job.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Mobile '
#                'Safari/537.36'}
# 2023-01-11 20:08:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-01-11 20:08:16 [scrapy.extensions.telnet] INFO: Telnet Password: 208abb080819e936
# 2023-01-11 20:08:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-01-11 20:08:16 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-01-11 20:08:16 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-01-11 20:08:17 [scrapy.middleware] INFO: Enabled item pipelines:
# ['parser_job.pipelines.ParserJobPipeline']
# 2023-01-11 20:08:17 [scrapy.core.engine] INFO: Spider opened
# 2023-01-11 20:08:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-01-11 20:08:17 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-01-11 20:08:18 [filelock] DEBUG: Attempting to acquire lock 139786207544848 on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:08:18 [filelock] DEBUG: Lock 139786207544848 acquired on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:08:18 [filelock] DEBUG: Attempting to acquire lock 139786207546864 on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2023-01-11 20:08:18 [filelock] DEBUG: Lock 139786207546864 acquired on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2023-01-11 20:08:18 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2023-01-11 20:08:18 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 81131
# 2023-01-11 20:08:18 [filelock] DEBUG: Attempting to release lock 139786207546864 on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2023-01-11 20:08:18 [filelock] DEBUG: Lock 139786207546864 released on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/urls/62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2023-01-11 20:08:18 [filelock] DEBUG: Attempting to release lock 139786207544848 on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:08:18 [filelock] DEBUG: Lock 139786207544848 released on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:08:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99> (referer: None)
# 2023-01-11 20:08:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73663412?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73663412?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17358e74336f0bc35f82'),
#  'company_name': 'ОООМакемаке',
#  'name': 'IT архитектор',
#  'salary': {'валюта': 'руб.', 'до': '', 'от': 40000},
#  'url': 'https://ufa.hh.ru/vacancy/73663412?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/72358031?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/72358031?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17358e74336f0bc35f83'),
#  'company_name': 'Тинькофф',
#  'name': 'Разработчик ETL',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/72358031?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/53942340?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/53942340?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17358e74336f0bc35f84'),
#  'company_name': 'ОООНПП Авиатрон',
#  'name': 'Ведущий инженер-программист АСУ ТП',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 100000},
#  'url': 'https://ufa.hh.ru/vacancy/53942340?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73095088?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73095088?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17368e74336f0bc35f85'),
#  'company_name': 'АОИнфоТеКС',
#  'name': 'DevOps / Инженер по сборке',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73095088?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73408249?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73408249?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17368e74336f0bc35f86'),
#  'company_name': 'EasyPro Academy',
#  'name': 'Преподаватель IT-дисциплин',
#  'salary': {'валюта': 'руб.', 'до': 64000, 'от': 24000},
#  'url': 'https://ufa.hh.ru/vacancy/73408249?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/75651487?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/75651487?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17378e74336f0bc35f87'),
#  'company_name': 'Школа программирования Учи.ру, г.Уфа (ИП Мамаев Евгений '
#                  'Алексеевич)',
#  'name': 'Преподаватель по программированию (для детей)',
#  'salary': {'валюта': 'руб.', 'до': 40000, 'от': 20000},
#  'url': 'https://ufa.hh.ru/vacancy/75651487?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73445045?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73445045?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17388e74336f0bc35f88'),
#  'company_name': 'ОООСДЛ-групп',
#  'name': 'Программист Python Django Middle',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 150000},
#  'url': 'https://ufa.hh.ru/vacancy/73445045?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/74036911?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/74036911?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17388e74336f0bc35f89'),
#  'company_name': 'ОООПромэкспертиза',
#  'name': 'Ведущий ГИС разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/74036911?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/74169102?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/74169102?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17398e74336f0bc35f8a'),
#  'company_name': 'Контур',
#  'name': 'Senior/Lead Python-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/74169102?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73443180?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73443180?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17398e74336f0bc35f8b'),
#  'company_name': 'Контур',
#  'name': 'Senior системный разработчик (python, Linux)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73443180?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/72358065?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/72358065?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173a8e74336f0bc35f8c'),
#  'company_name': 'Тинькофф',
#  'name': 'Data-инженер',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/72358065?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73863874?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73863874?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173b8e74336f0bc35f8d'),
#  'company_name': 'АОИнфоТеКС',
#  'name': 'Стажер (ручное тестирование, SIES)',
#  'salary': {'валюта': 'руб.', 'до': 20000, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73863874?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73741358?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73741358?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173c8e74336f0bc35f8e'),
#  'company_name': 'ОООРН-БашНИПИнефть',
#  'name': 'Python разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73741358?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/74408122?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/74408122?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173c8e74336f0bc35f8f'),
#  'company_name': 'ОООРН-БашНИПИнефть',
#  'name': 'Специалист по машинному обучению (Data scientist)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/74408122?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73057608?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73057608?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173d8e74336f0bc35f90'),
#  'company_name': 'АОИнфоТеКС',
#  'name': 'Ведущий разработчик Python',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73057608?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73901986?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73901986?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173e8e74336f0bc35f91'),
#  'company_name': 'Группа Компаний ОЗНА',
#  'name': 'Data Scientist (Junior/middle)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73901986?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73725391?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73725391?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173e8e74336f0bc35f92'),
#  'company_name': 'ОООЭлектронные платформы',
#  'name': 'Frontend-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73725391?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73309041?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73309041?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf173f8e74336f0bc35f93'),
#  'company_name': 'Тензор',
#  'name': 'Менеджер проекта',
#  'salary': {'валюта': 'руб.', 'до': 320000, 'от': 150000},
#  'url': 'https://ufa.hh.ru/vacancy/73309041?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/48224449?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/48224449?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17408e74336f0bc35f94'),
#  'company_name': 'Яндекс',
#  'name': 'Специалист службы поддержки с техническими знаниями (Контест)',
#  'salary': {'валюта': 'руб.', 'до': 39000, 'от': 15000},
#  'url': 'https://ufa.hh.ru/vacancy/48224449?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/71105981?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/71105981?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17408e74336f0bc35f95'),
#  'company_name': 'Directum',
#  'name': 'Senior .Net разработчик Directum RX',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/71105981?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/71106163?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/71106163?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17418e74336f0bc35f96'),
#  'company_name': 'Directum',
#  'name': 'Fullstack разработчик/Frontend',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/71106163?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/71105957?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/71105957?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17418e74336f0bc35f97'),
#  'company_name': 'Directum',
#  'name': 'Middle .Net разработчик Directum RX',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/71105957?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/72394409?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/72394409?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17428e74336f0bc35f98'),
#  'company_name': 'Directum',
#  'name': 'Fullstack разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/72394409?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/54852498?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/54852498?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17438e74336f0bc35f99'),
#  'company_name': 'ОООТагес Джамп',
#  'name': 'Golang Developer (Уфа)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 150000},
#  'url': 'https://ufa.hh.ru/vacancy/54852498?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73578639?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73578639?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17438e74336f0bc35f9a'),
#  'company_name': 'ПАОБАНК УРАЛСИБ',
#  'name': 'Аналитик дирекции бизнес-анализа процессов и продуктов',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/73578639?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/54852515?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99&page=1&hhtmFrom=vacancy_search_list)
# 2023-01-11 20:08:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/54852515?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17448e74336f0bc35f9b'),
#  'company_name': 'ОООТагес Джамп',
#  'name': 'DevOps-инженер (Middle)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 150000},
#  'url': 'https://ufa.hh.ru/vacancy/54852515?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/75230357?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/75230357?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17458e74336f0bc35f9c'),
#  'company_name': 'Homework',
#  'name': 'Автор работ по программированию Python',
#  'salary': {'валюта': 'руб.', 'до': 90000, 'от': None},
#  'url': 'https://ufa.hh.ru/vacancy/75230357?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/75451811?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/75451811?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17458e74336f0bc35f9d'),
#  'company_name': 'SMENA',
#  'name': 'Middle+ Python developer (team RnD)',
#  'salary': {'валюта': 'руб.', 'до': 190000, 'от': 150000},
#  'url': 'https://ufa.hh.ru/vacancy/75451811?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/74195506?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/74195506?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17468e74336f0bc35f9e'),
#  'company_name': 'ОООАк',
#  'name': 'Backend программист (Python)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 120000},
#  'url': 'https://ufa.hh.ru/vacancy/74195506?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.hh.ru/vacancy/73336372?from=vacancy_search_list&query=python> (referer: https://ufa.hh.ru/search/vacancy?text=python&from=suggest_post&area=99)
# 2023-01-11 20:08:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.hh.ru/vacancy/73336372?from=vacancy_search_list&query=python>
# {'_id': ObjectId('63bf17468e74336f0bc35f9f'),
#  'company_name': 'Центр технологий моделирования',
#  'name': 'Программист Python',
#  'salary': {'валюта': 'руб.', 'до': 150000, 'от': 100000},
#  'url': 'https://ufa.hh.ru/vacancy/73336372?from=vacancy_search_list&query=python'}
# 2023-01-11 20:08:38 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-01-11 20:08:38 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 24281,
#  'downloader/request_count': 32,
#  'downloader/request_method_count/GET': 32,
#  'downloader/response_bytes': 5043107,
#  'downloader/response_count': 32,
#  'downloader/response_status_count/200': 32,
#  'elapsed_time_seconds': 21.840973,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 1, 11, 20, 8, 38, 956066),
#  'httpcompression/response_bytes': 26603933,
#  'httpcompression/response_count': 32,
#  'item_scraped_count': 30,
#  'log_count/DEBUG': 73,
#  'log_count/INFO': 10,
#  'memusage/max': 78479360,
#  'memusage/startup': 78479360,
#  'request_depth_max': 2,
#  'response_received_count': 32,
#  'scheduler/dequeued': 32,
#  'scheduler/dequeued/memory': 32,
#  'scheduler/enqueued': 32,
#  'scheduler/enqueued/memory': 32,
#  'start_time': datetime.datetime(2023, 1, 11, 20, 8, 17, 115093)}
# 2023-01-11 20:08:38 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# !scrapy crawl rabota_ru
# Out:
# 2023-01-11 20:40:14 [scrapy.utils.log] INFO: Scrapy 2.7.1 started (bot: parser_job)
# 2023-01-11 20:40:14 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.8.16 (default, Dec  7 2022, 01:12:13) - [GCC 7.5.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 39.0.0, Platform Linux-5.10.147+-x86_64-with-glibc2.27
# 2023-01-11 20:40:14 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'parser_job',
#  'DOWNLOAD_DELAY': 0.5,
#  'NEWSPIDER_MODULE': 'parser_job.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['parser_job.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Mobile '
#                'Safari/537.36'}
# 2023-01-11 20:40:14 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-01-11 20:40:14 [scrapy.extensions.telnet] INFO: Telnet Password: 82ac31d364f5fdf6
# 2023-01-11 20:40:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-01-11 20:40:14 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-01-11 20:40:14 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-01-11 20:40:14 [scrapy.middleware] INFO: Enabled item pipelines:
# ['parser_job.pipelines.ParserJobPipeline']
# 2023-01-11 20:40:14 [scrapy.core.engine] INFO: Spider opened
# 2023-01-11 20:40:14 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-01-11 20:40:14 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-01-11 20:40:16 [filelock] DEBUG: Attempting to acquire lock 140697374244096 on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:40:16 [filelock] DEBUG: Lock 140697374244096 acquired on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:40:16 [filelock] DEBUG: Attempting to release lock 140697374244096 on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:40:16 [filelock] DEBUG: Lock 140697374244096 released on /root/.cache/python-tldextract/3.8.16.final__usr__7d8fdf__tldextract-3.4.0/publicsuffix.org-tlds/de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2023-01-11 20:40:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1> (referer: None)
# 2023-01-11 20:40:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47062623/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47062623/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb3164c5c13defc4809'),
#  'company_name': 'АктивБизнесКонсалт, ООО',
#  'name': 'Product Owner (Collection CRM-система)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47062623/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47062270/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:19 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47062270/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb3164c5c13defc480a'),
#  'company_name': 'АктивБизнесКонсалт, ООО',
#  'name': 'Team Lead Java developer',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47062270/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47172701/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47182162/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47172701/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb4164c5c13defc480b'),
#  'company_name': 'Работа.ру',
#  'name': 'Frontend-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47172701/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47182162/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb4164c5c13defc480c'),
#  'company_name': 'Томат и Чеддер',
#  'name': 'Разработчик PHP (удалённо)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 170000},
#  'url': 'https://ufa.rabota.ru/vacancy/47182162/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47169297/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47169297/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb4164c5c13defc480d'),
#  'company_name': 'Best Fabric',
#  'name': 'Контент-менеджер',
#  'salary': {'валюта': 'руб.', 'до': 30000, 'от': 20000},
#  'url': 'https://ufa.rabota.ru/vacancy/47169297/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47171668/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47171668/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb5164c5c13defc480e'),
#  'company_name': 'ООО "Империя Диджитал"',
#  'name': 'СЕО специалист',
#  'salary': {'валюта': 'руб.', 'до': 75000, 'от': 50000},
#  'url': 'https://ufa.rabota.ru/vacancy/47171668/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47165592/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:21 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47165592/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb5164c5c13defc480f'),
#  'company_name': 'Инновационные технологические решения развития',
#  'name': 'Developer IOS',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47165592/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/44719826/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/44719826/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb6164c5c13defc4810'),
#  'company_name': 'ООО "ВИСТЕРИЯ"',
#  'name': 'Администратор 1С',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/44719826/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47128667/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47128667/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb7164c5c13defc4811'),
#  'company_name': 'ООО "МЕГАБАЙТ ПЛЮС"',
#  'name': 'Программист 1С',
#  'salary': {'валюта': 'руб.', 'до': 100000, 'от': 80000},
#  'url': 'https://ufa.rabota.ru/vacancy/47128667/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47140685/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47140685/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb7164c5c13defc4812'),
#  'company_name': 'jobcart',
#  'name': 'IT-специалист',
#  'salary': {'валюта': 'руб.', 'до': 35000, 'от': 15000},
#  'url': 'https://ufa.rabota.ru/vacancy/47140685/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46836958/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46836958/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb8164c5c13defc4813'),
#  'company_name': 'Башкирэнерго',
#  'name': 'Ведущий инженер информационной безопасности (Башкирэнерго)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 70000},
#  'url': 'https://ufa.rabota.ru/vacancy/46836958/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47161891/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:24 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47161891/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb8164c5c13defc4814'),
#  'company_name': 'ООО Башмолснаб',
#  'name': 'Ведущий менеджер по работе с ключевыми клиентами',
#  'salary': {'валюта': 'руб.', 'до': 100000, 'от': 70000},
#  'url': 'https://ufa.rabota.ru/vacancy/47161891/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47164344/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47164344/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eb9164c5c13defc4815'),
#  'company_name': 'Башкирэнерго',
#  'name': 'Инженер технической поддержки',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 42000},
#  'url': 'https://ufa.rabota.ru/vacancy/47164344/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47038853/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47038853/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eba164c5c13defc4816'),
#  'company_name': 'Rambler&Co',
#  'name': 'Системный инженер (SaaS)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47038853/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47127997/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47127997/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eba164c5c13defc4817'),
#  'company_name': 'Jobers',
#  'name': 'Системный администратор',
#  'salary': {'валюта': 'руб.', 'до': 200000, 'от': 80000},
#  'url': 'https://ufa.rabota.ru/vacancy/47127997/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139931/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139931/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1ebb164c5c13defc4818'),
#  'company_name': 'СберМаркетинг',
#  'name': 'Аналитик в мобильную рекламу / Mobile analyst',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139931/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139965/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139965/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1ebb164c5c13defc4819'),
#  'company_name': 'SberMedAI',
#  'name': 'Программист Python (дистанционно)',
#  'salary': {'валюта': 'руб.', 'до': 230000, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139965/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46881571/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:28 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46881571/>
# {'_id': ObjectId('63bf1ebc164c5c13defc481a'),
#  'company_name': 'СберЗдоровье',
#  'name': 'QA Full Stack Engineer',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46881571/'}
# 2023-01-11 20:40:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47113550/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47113550/>
# {'_id': ObjectId('63bf1ebd164c5c13defc481b'),
#  'company_name': 'СберЗдоровье',
#  'name': 'Frontend react developer (remote)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47113550/'}
# 2023-01-11 20:40:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47113343/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47113343/>
# {'_id': ObjectId('63bf1ebe164c5c13defc481c'),
#  'company_name': 'Rambler&Co',
#  'name': 'Java-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47113343/'}
# 2023-01-11 20:40:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47113332/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47113332/>
# {'_id': ObjectId('63bf1ebf164c5c13defc481d'),
#  'company_name': 'Rambler&Co',
#  'name': 'Project Manager',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47113332/'}
# 2023-01-11 20:40:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47113542/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47113542/>
# {'_id': ObjectId('63bf1ebf164c5c13defc481e'),
#  'company_name': 'СберЗдоровье',
#  'name': 'Технический копирайтер / Tech PR',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47113542/'}
# 2023-01-11 20:40:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46826651/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46826651/>
# {'_id': ObjectId('63bf1ec0164c5c13defc481f'),
#  'company_name': 'СберЗдоровье',
#  'name': 'Backend Developer (PHP, Symfony)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46826651/'}
# 2023-01-11 20:40:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46511902/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46511902/>
# {'_id': ObjectId('63bf1ec0164c5c13defc4820'),
#  'company_name': 'СберЗдоровье',
#  'name': 'Mid+/ Sr Backend Developer (PHP)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46511902/'}
# 2023-01-11 20:40:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47038838/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47038838/>
# {'_id': ObjectId('63bf1ec1164c5c13defc4821'),
#  'company_name': 'Rambler&Co',
#  'name': 'Front end developer',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47038838/'}
# 2023-01-11 20:40:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46863746/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46863746/>
# {'_id': ObjectId('63bf1ec2164c5c13defc4822'),
#  'company_name': 'Rambler&Co',
#  'name': 'Системный архитектор (Отдел методологии IT)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46863746/'}
# 2023-01-11 20:40:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47038854/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47038854/>
# {'_id': ObjectId('63bf1ec2164c5c13defc4823'),
#  'company_name': 'Rambler&Co',
#  'name': 'Инженер - разработчик Ruby (Unity)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47038854/'}
# 2023-01-11 20:40:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47165390/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47165390/>
# {'_id': ObjectId('63bf1ec3164c5c13defc4824'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'PHP-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47165390/'}
# 2023-01-11 20:40:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47165419/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47165419/>
# {'_id': ObjectId('63bf1ec3164c5c13defc4825'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'PHP developer',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47165419/'}
# 2023-01-11 20:40:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47165421/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47165421/>
# {'_id': ObjectId('63bf1ec4164c5c13defc4826'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'QA Automation engineer 1С',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47165421/'}
# 2023-01-11 20:40:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47165306/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47165306/>
# {'_id': ObjectId('63bf1ec5164c5c13defc4827'),
#  'company_name': 'СберЛизинг',
#  'name': 'Администратор баз данных/DBA MS SQL',
#  'salary': {'валюта': 'руб.', 'до': 200000, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47165306/'}
# 2023-01-11 20:40:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47037763/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47037763/>
# {'_id': ObjectId('63bf1ec6164c5c13defc4828'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'Разработчик C# (.Net)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47037763/'}
# 2023-01-11 20:40:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46868945/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46868945/>
# {'_id': ObjectId('63bf1ec6164c5c13defc4829'),
#  'company_name': 'ООО ЦИТ "ФАКТ"',
#  'name': 'Bitrix разработчик',
#  'salary': {'валюта': 'руб.', 'до': 200000, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46868945/'}
# 2023-01-11 20:40:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/45630700/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/45630700/>
# {'_id': ObjectId('63bf1ec7164c5c13defc482a'),
#  'company_name': 'ООО "Зеленоглазое такси"',
#  'name': 'Тестировщик ПО (IOS)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 9999},
#  'url': 'https://ufa.rabota.ru/vacancy/45630700/'}
# 2023-01-11 20:40:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47138298/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47138298/>
# {'_id': ObjectId('63bf1ec8164c5c13defc482b'),
#  'company_name': 'ООО "КОМПАНИЯ ИНФОРУС"',
#  'name': 'Программист 1С',
#  'salary': {'валюта': 'руб.', 'до': 70000, 'от': 60000},
#  'url': 'https://ufa.rabota.ru/vacancy/47138298/'}
# 2023-01-11 20:40:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47212017/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47212017/>
# {'_id': ObjectId('63bf1ec9164c5c13defc482c'),
#  'company_name': 'Архи-веб',
#  'name': 'Контент-менеджер',
#  'salary': {'валюта': 'руб.', 'до': 68000, 'от': 47000},
#  'url': 'https://ufa.rabota.ru/vacancy/47212017/'}
# 2023-01-11 20:40:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47212207/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47212207/>
# {'_id': ObjectId('63bf1ec9164c5c13defc482d'),
#  'company_name': 'Центр сертификации и лицензирования',
#  'name': 'Оператор ПК/контент-менеджер',
#  'salary': {'валюта': 'руб.', 'до': 130000, 'от': 90000},
#  'url': 'https://ufa.rabota.ru/vacancy/47212207/'}
# 2023-01-11 20:40:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47015232/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47015232/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1eca164c5c13defc482e'),
#  'company_name': 'ПАО "Ростелеком"',
#  'name': 'Главный специалист информационной безопасности (endpoint security)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47015232/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=2)
# 2023-01-11 20:40:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46757339/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46757339/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1ecb164c5c13defc482f'),
#  'company_name': 'Rambler&Co',
#  'name': 'Системный инженер в инфраструĸтурную группу (DevOps)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46757339/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47166069/?search_id=16734696154231r7ietyp6g1> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=1)
# 2023-01-11 20:40:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47166069/?search_id=16734696154231r7ietyp6g1>
# {'_id': ObjectId('63bf1ecb164c5c13defc4830'),
#  'company_name': 'СберЗдоровье',
#  'name': 'DevOps Engineer',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47166069/?search_id=16734696154231r7ietyp6g1'}
# 2023-01-11 20:40:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139933/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139933/>
# {'_id': ObjectId('63bf1ecd164c5c13defc4831'),
#  'company_name': 'СберМаркетинг',
#  'name': 'Менеджер по продажам IT продуктов',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139933/'}
# 2023-01-11 20:40:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139762/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139762/>
# {'_id': ObjectId('63bf1ecd164c5c13defc4832'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'Разработчик 1С',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139762/'}
# 2023-01-11 20:40:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139647/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139647/>
# {'_id': ObjectId('63bf1ece164c5c13defc4833'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'Senior QA engineer (Специалист по тестированию ПО)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139647/'}
# 2023-01-11 20:40:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139747/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139747/>
# {'_id': ObjectId('63bf1ecf164c5c13defc4834'),
#  'company_name': 'ООО "Сберлогистика"',
#  'name': 'QA Automation engineer (Java)',
#  'salary': {'валюта': 'руб.', 'до': 270000, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139747/'}
# 2023-01-11 20:40:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47221123/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47221123/>
# {'_id': ObjectId('63bf1ecf164c5c13defc4835'),
#  'company_name': 'Jobers',
#  'name': 'Senior Backend разработчик (удаленно)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 125000},
#  'url': 'https://ufa.rabota.ru/vacancy/47221123/'}
# 2023-01-11 20:40:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47220673/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47220673/>
# {'_id': ObjectId('63bf1ed0164c5c13defc4836'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Тестировщик',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 46000},
#  'url': 'https://ufa.rabota.ru/vacancy/47220673/'}
# 2023-01-11 20:40:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47220672/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47220672/>
# {'_id': ObjectId('63bf1ed0164c5c13defc4837'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Тестировщик',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 46000},
#  'url': 'https://ufa.rabota.ru/vacancy/47220672/'}
# 2023-01-11 20:40:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47218242/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47218242/>
# {'_id': ObjectId('63bf1ed1164c5c13defc4838'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Оператор ПК/Контент-менеджер',
#  'salary': {'валюта': 'руб.', 'до': 130000, 'от': 90000},
#  'url': 'https://ufa.rabota.ru/vacancy/47218242/'}
# 2023-01-11 20:40:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47216235/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47216235/>
# {'_id': ObjectId('63bf1ed1164c5c13defc4839'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Контент-менеджер',
#  'salary': {'валюта': 'руб.', 'до': 25000, 'от': 20000},
#  'url': 'https://ufa.rabota.ru/vacancy/47216235/'}
# 2023-01-11 20:40:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47214077/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47214077/>
# {'_id': ObjectId('63bf1ed2164c5c13defc483a'),
#  'company_name': 'ООО "3Д СТУДИЯ"',
#  'name': 'Ведущий программист',
#  'salary': {'валюта': 'руб.', 'до': 200000, 'от': 100000},
#  'url': 'https://ufa.rabota.ru/vacancy/47214077/'}
# 2023-01-11 20:40:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47204436/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:50 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47204436/>
# {'_id': ObjectId('63bf1ed2164c5c13defc483b'),
#  'company_name': 'СберФакторинг',
#  'name': 'Java-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47204436/'}
# 2023-01-11 20:40:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47204437/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:51 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47204437/>
# {'_id': ObjectId('63bf1ed3164c5c13defc483c'),
#  'company_name': 'СберФакторинг',
#  'name': 'Java-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47204437/'}
# 2023-01-11 20:40:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47204435/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47204435/>
# {'_id': ObjectId('63bf1ed4164c5c13defc483d'),
#  'company_name': 'СберФакторинг',
#  'name': 'Java-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47204435/'}
# 2023-01-11 20:40:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47204434/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:52 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47204434/>
# {'_id': ObjectId('63bf1ed4164c5c13defc483e'),
#  'company_name': 'СберФакторинг',
#  'name': 'Java-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47204434/'}
# 2023-01-11 20:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47180898/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47180898/>
# {'_id': ObjectId('63bf1ed5164c5c13defc483f'),
#  'company_name': 'Союзмультфильм',
#  'name': 'Копирайтер (удалённо)',
#  'salary': {'валюта': 'руб.', 'до': 40000, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47180898/'}
# 2023-01-11 20:40:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47080836/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47080836/>
# {'_id': ObjectId('63bf1ed6164c5c13defc4840'),
#  'company_name': 'АктивБизнесКонсалт, ООО',
#  'name': 'Системный аналитик (Collection CRM-система)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47080836/'}
# 2023-01-11 20:40:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47211087/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:40:54 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47211087/>
# {'_id': ObjectId('63bf1ed6164c5c13defc4841'),
#  'company_name': 'ООО "АВТОХИЛЕР"',
#  'name': 'Web-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47211087/'}
# 2023-01-11 20:40:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47130342/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47130342/>
# {'_id': ObjectId('63bf1ed7164c5c13defc4842'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Начинающий менеджер по продажам в IT-компанию (удаленно)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 35000},
#  'url': 'https://ufa.rabota.ru/vacancy/47130342/'}
# 2023-01-11 20:40:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/46908610/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/46908610/>
# {'_id': ObjectId('63bf1ed7164c5c13defc4843'),
#  'company_name': 'Деловая среда, АО',
#  'name': 'Разработчик ПО (backend-разработчик на Java)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/46908610/'}
# 2023-01-11 20:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47133419/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47133419/>
# {'_id': ObjectId('63bf1ed8164c5c13defc4844'),
#  'company_name': 'Деловая среда, АО',
#  'name': 'Senior Java-разработчик',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47133419/'}
# 2023-01-11 20:40:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47133418/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47133418/>
# {'_id': ObjectId('63bf1ed8164c5c13defc4845'),
#  'company_name': 'Деловая среда, АО',
#  'name': 'QA Automation Engineer (Специалист по тестированию)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47133418/'}
# 2023-01-11 20:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47129255/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47129255/>
# {'_id': ObjectId('63bf1ed9164c5c13defc4846'),
#  'company_name': 'Boxberry',
#  'name': 'Программист 1С (УТ 11. 5)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 150000},
#  'url': 'https://ufa.rabota.ru/vacancy/47129255/'}
# 2023-01-11 20:40:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47129257/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47129257/>
# {'_id': ObjectId('63bf1ed9164c5c13defc4847'),
#  'company_name': 'Boxberry',
#  'name': 'Программист 1С (УТ 11. 5)',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 150000},
#  'url': 'https://ufa.rabota.ru/vacancy/47129257/'}
# 2023-01-11 20:40:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139492/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139492/>
# {'_id': ObjectId('63bf1eda164c5c13defc4848'),
#  'company_name': 'СберКорус',
#  'name': 'Руководитель группы java разработчиков',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139492/'}
# 2023-01-11 20:40:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139490/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139490/>
# {'_id': ObjectId('63bf1edb164c5c13defc4849'),
#  'company_name': 'СберКорус',
#  'name': 'ИТ-архитектор',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139490/'}
# 2023-01-11 20:40:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139479/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:40:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139479/>
# {'_id': ObjectId('63bf1edb164c5c13defc484a'),
#  'company_name': 'СберКорус',
#  'name': 'QA Manual тестировщик (Middle/Senior)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139479/'}
# 2023-01-11 20:41:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139472/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:41:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139472/>
# {'_id': ObjectId('63bf1edc164c5c13defc484b'),
#  'company_name': 'СберКорус',
#  'name': 'Java разработчик (проект ГАК)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139472/'}
# 2023-01-11 20:41:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139470/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:41:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139470/>
# {'_id': ObjectId('63bf1edd164c5c13defc484c'),
#  'company_name': 'СберКорус',
#  'name': 'Middle C# разработчик (удаленно)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139470/'}
# 2023-01-11 20:41:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139469/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:41:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139469/>
# {'_id': ObjectId('63bf1edd164c5c13defc484d'),
#  'company_name': 'СберКорус',
#  'name': 'Frontend Developer (Vue)',
#  'salary': {'валюта': None, 'до': None, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139469/'}
# 2023-01-11 20:41:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47139941/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=4)
# 2023-01-11 20:41:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47139941/>
# {'_id': ObjectId('63bf1ede164c5c13defc484e'),
#  'company_name': 'СберМаркетинг',
#  'name': 'DevOps инженер',
#  'salary': {'валюта': 'руб.', 'до': 325000, 'от': None},
#  'url': 'https://ufa.rabota.ru/vacancy/47139941/'}
# 2023-01-11 20:41:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47185419/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:41:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47185419/>
# {'_id': ObjectId('63bf1ede164c5c13defc484f'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Тестировщик',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 46000},
#  'url': 'https://ufa.rabota.ru/vacancy/47185419/'}
# 2023-01-11 20:41:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47185416/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:41:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47185416/>
# {'_id': ObjectId('63bf1edf164c5c13defc4850'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Тестировщик',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 44000},
#  'url': 'https://ufa.rabota.ru/vacancy/47185416/'}
# 2023-01-11 20:41:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://ufa.rabota.ru/vacancy/47177943/> (referer: https://ufa.rabota.ru/vacancy/?query=Developer%20python&sort=relevance&page=3)
# 2023-01-11 20:41:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://ufa.rabota.ru/vacancy/47177943/>
# {'_id': ObjectId('63bf1ee0164c5c13defc4851'),
#  'company_name': 'JCat, сервис размещения объявлений',
#  'name': 'Тестировщик',
#  'salary': {'валюта': 'руб.', 'до': None, 'от': 44000},
#  'url': 'https://ufa.rabota.ru/vacancy/47177943/'}
# 2023-01-11 20:41:04 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-01-11 20:41:04 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 284203,
#  'downloader/request_count': 77,
#  'downloader/request_method_count/GET': 77,
#  'downloader/response_bytes': 5658279,
#  'downloader/response_count': 77,
#  'downloader/response_status_count/200': 77,
#  'elapsed_time_seconds': 50.071379,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 1, 11, 20, 41, 4, 422049),
#  'httpcompression/response_bytes': 23588238,
#  'httpcompression/response_count': 77,
#  'item_scraped_count': 73,
#  'log_count/DEBUG': 155,
#  'log_count/INFO': 10,
#  'memusage/max': 78417920,
#  'memusage/startup': 78417920,
#  'request_depth_max': 4,
#  'response_received_count': 77,
#  'scheduler/dequeued': 77,
#  'scheduler/dequeued/memory': 77,
#  'scheduler/enqueued': 77,
#  'scheduler/enqueued/memory': 77,
#  'start_time': datetime.datetime(2023, 1, 11, 20, 40, 14, 350670)}
# 2023-01-11 20:41:04 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # 5. Проверка, что записалось в Mongo

# %%
from pymongo import MongoClient
client = MongoClient('127.0.0.1', 27017)
print(client.list_database_names())
db = client['db_vacancies']
print(db.list_collection_names())
# Out:
# ['admin', 'config', 'db_vacancies', 'local']
# ['hh_ru', 'rabota_ru']

# %% [markdown]
# # Запись в json

# %%
import json

class create_dict(dict): 
  
    # __init__ function 
    def __init__(self): 
        self = dict() 
          
    # Function to add key:value 
    def add(self, key, value): 
        self[key] = value 
        
mydict = create_dict()
i = 1
for mycol in db.list_collection_names():
  for y in db[mycol].find():
    mydict.add(i, ({"company_name'":y['company_name'],"vacancy_name":y['name'],"salary":y['salary'], "url": y['url']}))
    i = i+1
  f_name = f'{mycol}_json'
  print(f_name)
  with open(f_name, 'w', encoding='UTF-8') as f:
          json.dump(mydict, f)
  # f_name = json.dumps(mydict, indent=2, sort_keys=True)
# Out:
# hh_ru_json
# rabota_ru_json

# %%
with open('hh_ru_json', 'r', encoding='UTF-8') as f:
    HH = json.load(f)
print(f'hh_ru - количество вакансий в файле: {len(HH)}\n')
with open('rabota_ru_json', 'r', encoding='UTF-8') as f:
    RR = json.load(f)
print(f'Rabota.ru - количество вакансий в файле: {len(RR)}\n')
# Out:
# hh_ru - количество вакансий в файле: 30
#
# Rabota.ru - количество вакансий в файле: 405
